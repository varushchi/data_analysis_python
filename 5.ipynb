# %% [markdown]
# Вариант 21

# %%
import pandas as pd

# %%
df = pd.read_excel('./data5/Volgmed_2013.xlsx')
df
# Out:
#       Форма заполнения Unnamed: 1    Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                № п/п        Пол  Год рождения  Факультет       Курс
# 1                  104        жен          1981   лечебный          1
# 2                  104        жен          1981   лечебный          3
# 3                  NaN        NaN           NaN        NaN        NaN
# 4                  NaN        NaN           NaN        NaN        NaN
# ...                ...        ...           ...        ...        ...
# 12371              NaN        NaN           NaN        NaN        NaN
# 12372              NaN        NaN           NaN        NaN        NaN
# 12373              NaN        NaN           NaN        NaN        NaN
# 12374              NaN        NaN           NaN        NaN        NaN
# 12375              NaN        NaN           NaN        NaN        NaN
#
#       Unnamed: 5       Unnamed: 6           Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# ...
